# %%
import pandas as pd
import numpy as np
from datetime import datetime
import csv
import os

# %%
# Initialize the master DataFrame
master_df = pd.read_csv("ZIPdf.csv")
master_df.rename(columns={"Unnamed: 0" : "ZIP"}, inplace=True)
master_df["ZIP"] = master_df["ZIP"].astype(str).str.zfill(5)
master_df.set_index("ZIP", inplace=True)
master_df
# Out:
#        Num Farms  Num Estabs  Total Emp Bus  Min Share  Black Share  \
# ZIP
# 00501        0.0        10.0           10.0        NaN          NaN
# 01001       11.0       475.0          486.0   0.087898     0.028075
# 01002       60.0       502.0          562.0   0.257683     0.058108
# 01003        3.0        15.0           18.0   0.311443     0.044960
# 01004        3.0         6.0            9.0        NaN          NaN
# ...          ...         ...            ...        ...          ...
# 99926        1.0         9.0           10.0   0.890013     0.000000
# 99927        0.0         0.0            0.0        NaN          NaN
# 99928        1.0         4.0            5.0        NaN          NaN
# 99929        2.0        99.0          101.0   0.348346     0.003189
# 99950        3.0        11.0           14.0        NaN          NaN
#
#        Number of Loans_1  Total Loans Amount_1  Total Employees_1  \
# ZIP
# 00501                  0                     0                  0
# 01001                  0                     0                  0
# 01002                  0                     0                  0
# 01003                  0                     0                  0
# 01004                  0                     0                  0
# ...                  ...                   ...                ...
# 99926                  0                     0                  0
# 99927                  0                     0                  0
# 99928                  0                     0                  0
# 99929                  0                     0                  0
# 99950                  0                     0                  0
#
#        Number of Loans_2  Total Loans Amount_2  Total Employees_2  \
# ZIP
# 00501                  0                     0                  0
# 01001                  0                     0                  0
# 01002                  0                     0                  0
# 01003                  0                     0                  0
# 01004                  0                     0                  0
# ...                  ...                   ...                ...
# 99926                  0                     0                  0
# 99927                  0                     0                  0
# 99928                  0                     0                  0
# 99929                  0                     0                  0
# 99950                  0                     0                  0
#
#        Number of Loans_3  Total Loans Amount_3  Total Employees_3
# ZIP
# 00501                  0                     0                  0
# 01001                  0                     0                  0
# 01002                  0                     0                  0
# 01003                  0                     0                  0
# 01004                  0                     0                  0
# ...                  ...                   ...                ...
# 99926                  0                     0                  0
# 99927                  0                     0                  0
# 99928                  0                     0                  0
# 99929                  0                     0                  0
# 99950                  0                     0                  0
#
# [38100 rows x 14 columns]

# %%
# List of file names
base = "C:\\Users\\hthog\\Desktop\\PPP Loan Data\\"
file_df = pd.read_csv(base + "Files.csv")
file_df.drop(0, inplace=True) # Drop Test File
file_df
# Out:
#                                File  Completed
# 1    public_up_to_150k_1_230630.csv          0
# 2    public_up_to_150k_2_230630.csv          0
# 3    public_up_to_150k_3_230630.csv          0
# 4    public_up_to_150k_4_230630.csv          0
# 5    public_up_to_150k_5_230630.csv          0
# 6    public_up_to_150k_6_230630.csv          0
# 7    public_up_to_150k_7_230630.csv          0
# 8    public_up_to_150k_8_230630.csv          0
# 9    public_up_to_150k_9_230630.csv          0
# 10  public_up_to_150k_10_230630.csv          0
# 11  public_up_to_150k_11_230630.csv          0
# 12  public_up_to_150k_12_230630.csv          0

# %%
def assign_value_based_on_date(date):
    if date < pd.Timestamp('2020-04-17'):
        return '_1'
    elif date < pd.Timestamp('2020-08-09'):
        return '_2'
    else:
        return '_3'
traunches = ["_1", "_2", "_3"]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for file in file_df[file_df["Completed"] == 0]["File"]:
    file_name = base + file
    # Check if file exists
    if not os.path.exists(file_name):
        print(f"File {file_name} does not exist. Skipping...")
        continue

    print(f"Processing {file}...")
    
    # Read file row by row since cannot fit in DF
    with open("Problem Rows.txt", "a") as p:
        chunk_size = 80000
        for chunk in pd.read_csv(file_name, chunksize=chunk_size, usecols=['NonProfit', 
                                                                           'BusinessType', 
                                                                           'NAICSCode', 
                                                                           'BorrowerZip', 
                                                                           'DateApproved', 
                                                                           'InitialApprovalAmount', 
                                                                           'JobsReported']):
            # Filter chunk to only needed observations
            chunk = chunk[chunk["NonProfit"] != "Y"]
            chunk = chunk[~chunk["BusinessType"].isin(["Sole Proprietorship",
                                                      "Independent Contractors",
                                                      "Self-Employed Individuals"])]
            chunk = chunk[~chunk["NAICSCode"].isin([999990])]
            #chunk = chunk[chunk["NAICSCode"].notnull()]
            chunk.dropna(subset=["BorrowerZip"], inplace=True)

            # Edit chunk to include necessary info
            chunk["DateApproved"] = pd.to_datetime(chunk["DateApproved"])
            chunk["Traunch"] = chunk["DateApproved"].apply(assign_value_based_on_date)
            chunk["BorrowerZip"] = chunk["BorrowerZip"].astype(str).str[:5]
            
            # Aggregate Data
            grouped = chunk.groupby(['BorrowerZip', 'Traunch']).agg({
                'InitialApprovalAmount': 'sum',
                'JobsReported': 'sum',
                'Traunch': 'size'  # Count of loans
            })

            # Update master_df
            for (zip_, traunch), row in grouped.iterrows():
                if zip_ in master_df.index:
                    master_df.loc[zip_, f"Number of Loans{traunch}"] += row['Traunch']  # Update the number of loans
                    master_df.loc[zip_, f"Total Loans Amount{traunch}"] += row['InitialApprovalAmount']
                    master_df.loc[zip_, f"Total Employees{traunch}"] += row['JobsReported'] 
                else:
                    p.write(str(zip_) + "\n")
                    print("Error with ZIP Code: " + str(zip_))
                        
    file_df[file_df["File"] == file]["Completed"] = 1
    
    print(f"Updated master DataFrame with data from {file}.")
    
    # Ask for user confirmation to proceed to the next file
    user_input = input("Do you want to continue with the next file? (y/n): ")
    if user_input.lower() != 'y':
        print("Stopping the process.")
        # Save the master DataFrame to disk
        master_df.to_csv('ZIPdf.csv')
        file_df.to_csv(base + "Files.csv", index=False)
        break
# Out:
# Processing public_up_to_150k_1_230630.csv...
# Error with ZIP Code: 09724
# Error with ZIP Code: 09724
# Error with ZIP Code: 09803
# Error with ZIP Code: 35015
# Error with ZIP Code: 35086
# Error with ZIP Code: 35182
# Error with ZIP Code: 35220
# Error with ZIP Code: 35261
# Error with ZIP Code: 35295
# Error with ZIP Code: 35607
# Error with ZIP Code: 36118
# Error with ZIP Code: 36135
# Error with ZIP Code: 65404
# Error with ZIP Code: 96929
# Error with ZIP Code: 99697
# Error with ZIP Code: 99697
# Error with ZIP Code: 35246
# Error with ZIP Code: 36062
# Error with ZIP Code: 36640
# Error with ZIP Code: 03542
# Error with ZIP Code: 36508
# Error with ZIP Code: 36640
# Error with ZIP Code: 71748
# Error with ZIP Code: 72260
# Error with ZIP Code: 71748
# Error with ZIP Code: 72369
# Error with ZIP Code: 85106
# Error with ZIP Code: 85220
# Error with ZIP Code: 85294
# Error with ZIP Code: 86026
# Error with ZIP Code: 96799
# Error with ZIP Code: 96799
# Error with ZIP Code: 96799
# Error with ZIP Code: 85220
# Error with ZIP Code: 88537
# Error with ZIP Code: 85058
# Error with ZIP Code: 85242
# Error with ZIP Code: 92137
# Error with ZIP Code: 94926
# Error with ZIP Code: 95026
# Error with ZIP Code: 98212
# Error with ZIP Code: 00092
# Error with ZIP Code: 90081
# Error with ZIP Code: 90273
# Error with ZIP Code: 91609
# Error with ZIP Code: 92814
# Error with ZIP Code: 92815
# Error with ZIP Code: 93590
# Error with ZIP Code: 93793
# Error with ZIP Code: 94661
# Error with ZIP Code: 94883
# Error with ZIP Code: 95214
# Error with ZIP Code: 95644
# Error with ZIP Code: 95766
# Error with ZIP Code: 96214
# Error with ZIP Code: 90624
# Error with ZIP Code: 91333
# Error with ZIP Code: 91435
# Error with ZIP Code: 91952
# Error with ZIP Code: 92053
# Error with ZIP Code: 92522
# Error with ZIP Code: 92750
# Error with ZIP Code: 92876
# Error with ZIP Code: 93233
# Error with ZIP Code: 93707
# Error with ZIP Code: 94250
# Error with ZIP Code: 95105
# Error with ZIP Code: 95723
# Error with ZIP Code: 95785
# Error with ZIP Code: 95865
# Error with ZIP Code: 95866
# Error with ZIP Code: 90072
# Error with ZIP Code: 90271
# Error with ZIP Code: 90310
# Error with ZIP Code: 91115
# Error with ZIP Code: 91115
# Error with ZIP Code: 91121
# Error with ZIP Code: 91561
# Error with ZIP Code: 92522
# Error with ZIP Code: 92640
# Error with ZIP Code: 92921
# Error with ZIP Code: 93118
# Error with ZIP Code: 94227
# Error with ZIP Code: 94820
# Error with ZIP Code: 95071
# Error with ZIP Code: 95281
# Error with ZIP Code: 90331
# Error with ZIP Code: 90671
# Error with ZIP Code: 91110
# Error with ZIP Code: 91394
# Error with ZIP Code: 91734
# Error with ZIP Code: 91804
# Error with ZIP Code: 92179
# Error with ZIP Code: 92723
# Error with ZIP Code: 92820
# Error with ZIP Code: 93590
# Error with ZIP Code: 94614
# Error with ZIP Code: 94661
# Error with ZIP Code: 95103
# Error with ZIP Code: 29106
# Error with ZIP Code: 90361
# Error with ZIP Code: 91129
# Error with ZIP Code: 91394
# Error with ZIP Code: 91976
# Error with ZIP Code: 92174
# Error with ZIP Code: 92179
# Error with ZIP Code: 93502
# Error with ZIP Code: 94172
# Updated master DataFrame with data from public_up_to_150k_1_230630.csv.
# Do you want to continue with the next file? (y/n): y
# Processing public_up_to_150k_2_230630.csv...
# Error with ZIP Code: 91394
# Error with ZIP Code: 20278
# Error with ZIP Code: 91041
# Error with ZIP Code: 91225
# Error with ZIP Code: 93586
# Error with ZIP Code: 94016
# Error with ZIP Code: 95860
# Error with ZIP Code: 90227
# Error with ZIP Code: 91707
# Error with ZIP Code: 91976
# Error with ZIP Code: 92051
# Error with ZIP Code: 94410
# Error with ZIP Code: 94661
# Error with ZIP Code: 94913
# Error with ZIP Code: 94913
# Error with ZIP Code: 95533
# Error with ZIP Code: 95860
# Error with ZIP Code: 91041
# Error with ZIP Code: 92669
# Error with ZIP Code: 93760
# Error with ZIP Code: 94341
# Error with ZIP Code: 94821
# Error with ZIP Code: 92735
# Error with ZIP Code: 94615
# Error with ZIP Code: 91041
# Error with ZIP Code: 91394
# Error with ZIP Code: 92153
# Error with ZIP Code: 92174
# Error with ZIP Code: 92174
# Error with ZIP Code: 92302
# Error with ZIP Code: 96079
# Error with ZIP Code: 98060
# Error with ZIP Code: 62064
# Error with ZIP Code: 82344
# Error with ZIP Code: 91609
# Error with ZIP Code: 92051
# Error with ZIP Code: 94172
# Error with ZIP Code: 95071
# Error with ZIP Code: 91225
# Error with ZIP Code: 94250
# Error with ZIP Code: 80036
# Error with ZIP Code: 80826
# Error with ZIP Code: 81260
# Error with ZIP Code: 80165
# Error with ZIP Code: 80256
# Error with ZIP Code: 80932
# Error with ZIP Code: 80932
# Error with ZIP Code: 06077
# Error with ZIP Code: 06104
# Error with ZIP Code: 06126
# Error with ZIP Code: 06126
# Error with ZIP Code: 06138
# Error with ZIP Code: 06146
# Error with ZIP Code: 06147
# Error with ZIP Code: 06230
# Error with ZIP Code: 06233
# Error with ZIP Code: 06487
# Error with ZIP Code: 06535
# Error with ZIP Code: 06723
# Error with ZIP Code: 06726
# Error with ZIP Code: 06879
# Error with ZIP Code: 06879
# Error with ZIP Code: 06911
# Error with ZIP Code: 06911
# Error with ZIP Code: 06911
# Error with ZIP Code: 11111
# Error with ZIP Code: 16498
# Error with ZIP Code: 80036
# Error with ZIP Code: 06404
# Error with ZIP Code: 06493
# Error with ZIP Code: 65130
# Updated master DataFrame with data from public_up_to_150k_2_230630.csv.
# Do you want to continue with the next file? (y/n): y
# Processing public_up_to_150k_3_230630.csv...
# Error with ZIP Code: 06025
# Error with ZIP Code: 06126
# Error with ZIP Code: 06132
# Error with ZIP Code: 06138
# Error with ZIP Code: 06140
# Error with ZIP Code: 06493
# Error with ZIP Code: 06530
# Error with ZIP Code: 06723
# Error with ZIP Code: 06911
# Error with ZIP Code: 19712
# Error with ZIP Code: 20033
# Error with ZIP Code: 20035
# Error with ZIP Code: 20040
# Error with ZIP Code: 20040
# Error with ZIP Code: 20043
# Error with ZIP Code: 20056
# Error with ZIP Code: 20229
# Error with ZIP Code: 20229
# Error with ZIP Code: 20403
# Error with ZIP Code: 26765
# Error with ZIP Code: 65160
# Error with ZIP Code: 11496
# Error with ZIP Code: 32870
# Error with ZIP Code: 33188
# Error with ZIP Code: 32030
# Error with ZIP Code: 32556
# Error with ZIP Code: 33188
# Error with ZIP Code: 33466
# Error with ZIP Code: 34692
# Error with ZIP Code: 32231
# Error with ZIP Code: 32556
# Error with ZIP Code: 33238
# Error with ZIP Code: 33333
# Error with ZIP Code: 33630
# Error with ZIP Code: 33661
# Error with ZIP Code: 34218
# Error with ZIP Code: 34410
# Error with ZIP Code: 34487
# Error with ZIP Code: 88183
# Error with ZIP Code: 34562
# Error with ZIP Code: 32231
# Error with ZIP Code: 33238
# Error with ZIP Code: 32125
# Error with ZIP Code: 34692
# Error with ZIP Code: 33342
# Error with ZIP Code: 33464
# Error with ZIP Code: 34673
# Error with ZIP Code: 34713
# Error with ZIP Code: 34713
# Error with ZIP Code: 33078
# Error with ZIP Code: 33089
# Error with ZIP Code: 33623
# Error with ZIP Code: 34281
# Error with ZIP Code: 34713
# Error with ZIP Code: 31654
# Error with ZIP Code: 34244
# Error with ZIP Code: 34692
# Error with ZIP Code: 33112
# Updated master DataFrame with data from public_up_to_150k_3_230630.csv.
# Do you want to continue with the next file? (y/n): y
# Processing public_up_to_150k_4_230630.csv...
# Error with ZIP Code: 33630
# Error with ZIP Code: 30026
# Error with ZIP Code: 30353
# Error with ZIP Code: 30388
# Error with ZIP Code: 30392
# Error with ZIP Code: 30394
# Error with ZIP Code: 30394
# Error with ZIP Code: 31141
# Error with ZIP Code: 31141
# Error with ZIP Code: 33630
# Error with ZIP Code: 07200
# Error with ZIP Code: 30027
# Error with ZIP Code: 30167
# Error with ZIP Code: 31786
# Error with ZIP Code: 30160
# Error with ZIP Code: 30819
# Error with ZIP Code: 50981
# Error with ZIP Code: 96802
# Error with ZIP Code: 96802
# Error with ZIP Code: 96803
# Error with ZIP Code: 96804
# Error with ZIP Code: 96805
# Error with ZIP Code: 96805
# Error with ZIP Code: 96807
# Error with ZIP Code: 96836
# Error with ZIP Code: 96836
# Error with ZIP Code: 96844
# Error with ZIP Code: 96910
# Error with ZIP Code: 96910
# Error with ZIP Code: 96910
# Error with ZIP Code: 96912
# Error with ZIP Code: 96912
# Error with ZIP Code: 96913
# Error with ZIP Code: 96913
# Error with ZIP Code: 96913
# Error with ZIP Code: 96915
# Error with ZIP Code: 96915
# Error with ZIP Code: 96915
# Error with ZIP Code: 96916
# Error with ZIP Code: 96917
# Error with ZIP Code: 96919
# Error with ZIP Code: 96921
# Error with ZIP Code: 96921
# Error with ZIP Code: 96921
# Error with ZIP Code: 96928
# Error with ZIP Code: 96928
# Error with ZIP Code: 96929
# Error with ZIP Code: 96929
# Error with ZIP Code: 96929
# Error with ZIP Code: 96931
# Error with ZIP Code: 96931
# Error with ZIP Code: 96931
# Error with ZIP Code: 96932
# Error with ZIP Code: 96932
# Error with ZIP Code: 96932
# Error with ZIP Code: 50427
# Error with ZIP Code: 50427
# Error with ZIP Code: 52504
# Error with ZIP Code: 50592
# Error with ZIP Code: 52149
# Error with ZIP Code: 52409
# Error with ZIP Code: 82813
# Error with ZIP Code: 83865
# Error with ZIP Code: 83865
# Updated master DataFrame with data from public_up_to_150k_4_230630.csv.
# Do you want to continue with the next file? (y/n): n
# Stopping the process.

# %%
# master_df["Number of Loans_1"] = 0
# master_df["Total Loans Amount_1"] = 0
# master_df["Total Employees_1"] = 0

# master_df["Number of Loans_2"] = 0
# master_df["Total Loans Amount_2"] = 0
# master_df["Total Employees_2"] = 0

# master_df["Number of Loans_3"] = 0
# master_df["Total Loans Amount_3"] = 0
# master_df["Total Employees_3"] = 0

# master_df.to_csv("ZIPdf.csv")

# %%
master_df.loc["72704"]
# Out:
# Num Farms               2.050000e+02
# Num Estabs              5.060000e+02
# Total Emp Bus           7.110000e+02
# Min Share               1.583459e-01
# Black Share             5.332326e-02
# Number of Loans_1       1.180000e+02
# Total Loans Amount_1    5.284223e+06
# Total Employees_1       8.160000e+02
# Number of Loans_2       7.800000e+01
# Total Loans Amount_2    1.654617e+06
# Total Employees_2       2.870000e+02
# Number of Loans_3       9.500000e+01
# Total Loans Amount_3    2.938545e+06
# Total Employees_3       6.120000e+02
# Name: 72704, dtype: float64
